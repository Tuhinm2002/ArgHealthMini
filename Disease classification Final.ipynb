# %%
import pickle
import numpy as np
import pandas as pd

# %%
Precaution=pickle.load(open('Precaution.pkl','rb'))
Severity=pickle.load(open('Severity.pkl','rb'))
Description=pickle.load(open('Description.pkl','rb'))

# %%
df=pd.read_csv('Cleaned_data.csv')

# %%
for j in range(len(df.Symptom_2)):
    if df.Symptom_2[j]==140:
        continue
    df.Symptom_2[j]=Severity[df.Symptom_2[j]]

for j in range(len(df.Symptom_1)):
    if df.Symptom_1[j]==140:
        continue
    df.Symptom_1[j]=Severity[df.Symptom_1[j]]

for j in range(len(df.Symptom_3)):
    if df.Symptom_3[j]==140:
        continue
    df.Symptom_3[j]=Severity[df.Symptom_3[j]]
    
for j in range(len(df.Symptom_4)):
    if df.Symptom_4[j]==140:
        continue
    df.Symptom_4[j]=Severity[df.Symptom_4[j]]
    
for j in range(len(df.Symptom_5)):
    if df.Symptom_5[j]==140:
        continue
    df.Symptom_5[j]=Severity[df.Symptom_5[j]]
    
for j in range(len(df.Symptom_6)):
    if df.Symptom_6[j]==140:
        continue
    df.Symptom_6[j]=Severity[df.Symptom_6[j]]
        
for j in range(len(df.Symptom_7)):
    if df.Symptom_7[j]==140:
        continue
    df.Symptom_7[j]=Severity[df.Symptom_7[j]]

for j in range(len(df.Symptom_8)):
    if df.Symptom_8[j]==140:
        continue
    df.Symptom_8[j]=Severity[df.Symptom_8[j]]
        
for j in range(len(df.Symptom_9)):
    if df.Symptom_9[j]==140:
        continue
    df.Symptom_9[j]=Severity[df.Symptom_9[j]]
        
for j in range(len(df.Symptom_10)):
    if df.Symptom_10[j]==140:
        continue
    df.Symptom_10[j]=Severity[df.Symptom_10[j]]
        
for j in range(len(df.Symptom_11)):
    if df.Symptom_11[j]==140:
        continue
    df.Symptom_11[j]=Severity[df.Symptom_11[j]]
        
for j in range(len(df.Symptom_12)):
    if df.Symptom_12[j]==140:
        continue
    df.Symptom_12[j]=Severity[df.Symptom_12[j]]
        
for j in range(len(df.Symptom_13)):
    if df.Symptom_13[j]==140:
        continue
    df.Symptom_13[j]=Severity[df.Symptom_13[j]]
        
for j in range(len(df.Symptom_14)):
    if df.Symptom_14[j]==140:
        continue
    df.Symptom_14[j]=Severity[df.Symptom_14[j]]
        
for j in range(len(df.Symptom_15)):
    if df.Symptom_15[j]==140:
        continue
    df.Symptom_15[j]=Severity[df.Symptom_15[j]]
        
for j in range(len(df.Symptom_16)):
    if df.Symptom_16[j]==140:
        continue
    df.Symptom_16[j]=Severity[df.Symptom_16[j]]
        
for j in range(len(df.Symptom_17)):
    if df.Symptom_17[j]==140:
        continue
    df.Symptom_17[j]=Severity[df.Symptom_17[j]]
# Out:
# /tmp/ipykernel_6272/870388752.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Symptom_2[j]=Severity[df.Symptom_2[j]]
# /tmp/ipykernel_6272/870388752.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Symptom_1[j]=Severity[df.Symptom_1[j]]
# /tmp/ipykernel_6272/870388752.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Symptom_3[j]=Severity[df.Symptom_3[j]]
# ...

# %%
df
# Out:
#       Unnamed: 0                                  Disease  Symptom_1  \
# 0              0                         Fungal infection          1
# 1              1                         Fungal infection          3
# 2              2                         Fungal infection          1
# 3              3                         Fungal infection          1
# 4              4                         Fungal infection          1
# ...          ...                                      ...        ...
# 4915        4915  (vertigo) Paroymsal  Positional Vertigo          5
# 4916        4916                                     Acne          3
# 4917        4917                  Urinary tract infection          6
# 4918        4918                                Psoriasis          3
# 4919        4919                                 Impetigo          3
#
#       Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6  Symptom_7  \
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.to_csv('Final.csv')

# %%
data=pd.read_csv('Final.csv')

# %%
Y=data.iloc[:,1]
X=data.iloc[:,2:]

# %%
Y_re=[]
n_unique=len(Y.unique())
for j in range(n_unique):
    Y_re.append(Y.unique()[j])
Y_dict={x:i for i,x in enumerate(Y_re)}
y=[]
for i in Y:
    y.append(Y_dict[i])

# %%
Y.unique()
# Out:
# array(['Fungal infection', 'Allergy', 'GERD', 'Chronic cholestasis',
#        'Drug Reaction', 'Peptic ulcer diseae', 'AIDS', 'Diabetes ',
#        'Gastroenteritis', 'Bronchial Asthma', 'Hypertension ', 'Migraine',
#        'Cervical spondylosis', 'Paralysis (brain hemorrhage)', 'Jaundice',
#        'Malaria', 'Chicken pox', 'Dengue', 'Typhoid', 'hepatitis A',
#        'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E',
#        'Alcoholic hepatitis', 'Tuberculosis', 'Common Cold', 'Pneumonia',
#        'Dimorphic hemmorhoids(piles)', 'Heart attack', 'Varicose veins',
#        'Hypothyroidism', 'Hyperthyroidism', 'Hypoglycemia',
#        'Osteoarthristis', 'Arthritis',
#        '(vertigo) Paroymsal  Positional Vertigo', 'Acne',
#        'Urinary tract infection', 'Psoriasis', 'Impetigo'], dtype=object)

# %%
y_np=np.asarray(y)
X_np=X.to_numpy()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_np,y_np,random_state=42,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier
dte=DecisionTreeClassifier()
dte.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=dte.predict(x_test)
acc=accuracy_score(y_pred,y_test)

# %%
acc
# Out:
# 0.9939024390243902

# %%
pickle.dump(dte,open('Model.pkl','wb'))
